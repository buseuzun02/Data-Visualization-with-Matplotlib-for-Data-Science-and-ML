# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x,y)
plt.show()

# %%
# 1st methd
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
# %matplotlib inline
fig = plt.figure() # creates figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# 3rd method 
# subplot : aynıı nda birden fazla olay örgüsünün ortaya çıkması 
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]);
plt.show()

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. prepare data 
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. setup plot
fig, ax = plt.subplots(figsize=(10, 10)) # width and height 

# 3.plot data
ax.plot(x, y)

# 4. customize plot
ax.set(title="Simple Plot",
          xlabel="x-axis",
          ylabel="y-axis")

# 5. save & show (you save the whole figure)
plt.show()
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line plot
# * scatter plot
# * bar plot
# * histogram
# * subplots

# %%
import numpy as np

# %%
# create some data
# linspace : belirli bir aralıkta eşit aralıklı sayılar döndürür
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plot data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2)
plt.show()

# %%
# use same data to make a scatter 
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))
plt.show()

# %%
# make plot from dictionary 
nut_butter_prices = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Buse's Nut Butter Store",
      ylabel="Prices ($)")
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
plt.show()

# %%
# make some data
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# ## two options for subplots

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5))
# plot to each different axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.rand(1000))
plt.show()

# %%
# subplots options 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10, 5))
# plot to each different  index
ax[0, 0].plot(x, x/2)
ax[0 ,1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
plt.show()

# %% [markdown]
# ## Potting  from pandas DataFrames

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2024', periods=1000))
ts = ts.cumsum() #kümülatif toplam 
ts.plot()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].replace(r'[\$\,\.]', '', regex=True).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].astype(str)
type(car_sales["Price"][0])
# Out:
# str

# %%
# remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
#lets plot the total sale
car_sales.plot(x="Sale Date", y="Total Sales")
plt.show()

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
plt.show()

# %%
# how about bar graph 
x = np.random.randn(10, 4)
x

# turn it into a dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.638009 -0.346620  1.155588 -0.434491
# 1 -0.315209 -0.484979 -1.449288  1.362705
# 2 -1.798840  1.144396  0.538787 -0.239371
# 3  1.109633  0.943908 -0.978133  2.387770
# 4  0.395355 -1.575332 -0.185703 -1.608556
# 5 -1.420718 -0.455551 -0.707631 -1.301589
# 6 -1.428226  0.742792 -0.370264  0.390505
# 7  0.246498  0.545997  1.724907  1.010633
# 8  0.614026 -1.878845 -0.031482 -0.054052
# 9 -0.115511  1.210990 -2.572044 -0.993409

# %%
df.plot.bar()
plt.show()

# %%
df.plot(kind="bar")
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x="Make",
              y="Odometer (KM)",
              kind="bar")
plt.show()

# %%
# how about histogram
car_sales["Odometer (KM)"].plot.hist()
plt.show()

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
plt.show()

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20)
plt.show()

# %%
# lets try another data set
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# create a histogram
heart_disease["age"].plot.hist()
plt.show()

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True)
plt.show()

# %% [markdown]
# ### which one should you use? (pyplot vs matplotlib OO method)
# * when plot something quick -> pyplot method
# * when plotting more advanced -> OO method

# %%
over_50 = heart_disease[heart_disease["age"]> 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target')
plt.show()

# %%
# OO method mix pyplot method
fix, ax= plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax)
plt.show()

# %%
fix, ax= plt.subplots(figsize=(10, 6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax)
ax.set_xlim([45, 100])
plt.show()

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

## plot the data 
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])
# custumize the plot
ax.set(title="Heart Disease and Chol levels",
      xlabel="Age",
      ylabel="Cholestrol")
# add alegend 
ax.legend(*scatter.legend_elements(), title="Target")

# add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--")

plt.show()

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# subplot of chol, age, thalach (max heart beat)

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True)
# add data x0 
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])
# custumize ax0
ax0.set(title="Heart Disease and Chol Level",
       ylabel="Cholestrol")

# add a legend at x0
ax0.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--")

# add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])

# custumize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")

# adda legend 
ax1.legend(*scatter.legend_elements(), title="Target")

# add a meanline 
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--")

# add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
plt.show()

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
# see the different styles availible 
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500

# %%
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use('seaborn-v0_8')
car_sales["Price"].plot()
plt.show()

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
plt.show()

# %%
plt.style.use('ggplot')
car_sales["Price"].plot()
plt.show()

# %%
# Create some data
x = np.random.randn(10, 4)
x
# Out:
# array([[ 0.60548865,  1.23127314, -0.08840405,  2.48967752],
#        [-1.20192198,  0.91146197, -0.53358309, -0.73534907],
#        [-0.38320318, -0.47569174, -0.53747331, -1.47516597],
#        [-0.89536301,  0.30297632,  0.53350169,  0.37423018],
#        [ 0.31298539, -0.76218411,  0.09434416,  0.19074112],
#        [-0.29342681,  1.12877036,  0.86354274,  1.75496669],
#        [-0.84299435,  1.04040903, -0.18638569, -1.03867534],
#        [-1.55578265,  1.02346789,  0.23014857,  0.83599758],
#        [-0.85325182,  1.23657733, -0.10551217, -0.9858126 ],
#        [-0.50756072, -1.90980429,  1.19063132,  0.35803039]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.605489  1.231273 -0.088404  2.489678
# 1 -1.201922  0.911462 -0.533583 -0.735349
# 2 -0.383203 -0.475692 -0.537473 -1.475166
# 3 -0.895363  0.302976  0.533502  0.374230
# 4  0.312985 -0.762184  0.094344  0.190741
# 5 -0.293427  1.128770  0.863543  1.754967
# 6 -0.842994  1.040409 -0.186386 -1.038675
# 7 -1.555783  1.023468  0.230149  0.835998
# 8 -0.853252  1.236577 -0.105512 -0.985813
# 9 -0.507561 -1.909804  1.190631  0.358030

# %%
ax = df.plot(kind='bar')
plt.show()

# %%
# customize our plot with the set() method
ax = df.plot(kind="bar")
# add some labels and title 
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row number",
      ylabel="Random numbers")
# make the legend visible
ax.legend().set_visible(True)
plt.show()

# %%
# set the syle
plt.style.use('seaborn-v0_8-whitegrid')

# subplot of chol, age, thalach (max heart beat)

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True)
# add data x0 
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter") # change the colour scheme
# custumize ax0
ax0.set(title="Heart Disease and Chol Level",
       ylabel="Cholestrol")

# add a legend at x0
ax0.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--")

# add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter")

# custumize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")

# adda legend 
ax1.legend(*scatter.legend_elements(), title="Target")

# add a meanline 
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--")

# add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
plt.show()

# %%
# set the syle
plt.style.use('seaborn-v0_8-whitegrid')

# subplot of chol, age, thalach (max heart beat)

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True)
# add data x0 
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter") # change the colour scheme
# custumize ax0
ax0.set(title="Heart Disease and Chol Level",
       ylabel="Cholestrol")
# change the x axis limits
ax0.set_xlim([50, 80])

# add a legend at x0
ax0.legend(*scatter.legend_elements(), title="Target")

# add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--")

# add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter")

# custumize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")

# change the x axis limits
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])
# adda legend 
ax1.legend(*scatter.legend_elements(), title="Target")

# add a meanline 
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--")

# add a title to figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
plt.show()

# %%
fig

# %%
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
